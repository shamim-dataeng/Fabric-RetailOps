-- %%
CREATE SCHEMA IF NOT EXISTS bronze;
-- Out:
-- StatementMeta(, a5429714-aed5-493e-89a8-c81dd4d166f6, 2, Finished, Available, Finished, False)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE SCHEMA IF NOT EXISTS silver;
-- Out:
-- StatementMeta(, a5429714-aed5-493e-89a8-c81dd4d166f6, 3, Finished, Available, Finished, False)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
CREATE SCHEMA IF NOT EXISTS gold;
-- Out:
-- StatementMeta(, a5429714-aed5-493e-89a8-c81dd4d166f6, 4, Finished, Available, Finished, False)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
SELECT *
FROM bronze.bronze_orders_batch
LIMIT 10;
-- Out:
-- StatementMeta(, 9d51311f-9631-46d3-a35c-f6188325ebe6, 4, Finished, Available, Finished, False)
-- <Spark SQL result set with 10 rows and 12 fields>

-- %%
SELECT
    COUNT(*) AS total_records
FROM 
    bronze.bronze_orders_batch;
-- Out:
-- StatementMeta(, 9d51311f-9631-46d3-a35c-f6188325ebe6, 5, Finished, Available, Finished, False)
-- <Spark SQL result set with 1 rows and 1 fields>

-- %%
SELECT
    COUNT(*) AS total_records
FROM 
    bronze.dim_customers;
-- Out:
-- StatementMeta(, 9d51311f-9631-46d3-a35c-f6188325ebe6, 6, Finished, Available, Finished, False)
-- <Spark SQL result set with 1 rows and 1 fields>

-- %%
SELECT
    COUNT(*) AS total_records
FROM 
    bronze.dim_products;
-- Out:
-- StatementMeta(, 9d51311f-9631-46d3-a35c-f6188325ebe6, 7, Finished, Available, Finished, False)
-- <Spark SQL result set with 1 rows and 1 fields>

-- %%
SELECT
    COUNT(*) AS total_records
FROM 
    bronze.bronze_orders_stream;
-- Out:
-- StatementMeta(, 684077e6-0fb8-4ad5-9598-62f3e6c99c1c, 2, Finished, Available, Finished, False)
-- <Spark SQL result set with 1 rows and 1 fields>
